# %% [markdown]
# # KNN Lab (10 pts)

# %% [markdown]
# ## 准备工作
# ### 环境准备
# 请确保完成以下依赖包的安装，并且通过下面代码来导入与验证。

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from autograder import *
from vis_util import *
from codes import *

# reload modifications on imported modules
# %load_ext autoreload
# %autoreload 2

np.random.seed(12)

# %% [markdown]
# ### 数据集准备
# 为了进行实验，我们提供了一个包含三个簇的训练样本集。该数据集包含两个特征（features），以及一个标签 y。
#
# 请执行以下代码以加载数据集并进行可视化。

# %%
from data_generator import gen_2D_dataset

# define the centers of different classes
centers = [[1, 1], [-1, -1], [1, -1]]
# define the number of samples
n_samples = 500
cluster_std = 0.8

# generate the dataset
x_train, y_train = gen_2D_dataset(centers, n_samples, cluster_std)
x_test, y_test = gen_2D_dataset(centers, 100, cluster_std)

# %%
from vis_util import visualize_2D_dataset

# visualize the dataset
visualize_2D_dataset(x_train, y_train)

# %% [markdown]
# ## KNN
#
# KNN 算法的核心思想是利用距离待预测点最近的$K$个样本数据的分类来代表/预测目标数据的分类。
#
# 请完成`codes.py`文件中的以下函数：
#
# 1. **定义距离函数（Distance Function）： 在这里，我们将采用欧式距离`euclidean_distance()`; (3 pts)**
# 2. **利用 KNN 算法进行预测 `KNN_predict()`; (7 pts)**
#
# 你将需要使用到 `numpy` 库，可以参考 [NumPy 官方文档](https://numpy.org/doc/stable/user/index.html) 。
#
# 你可能会用到的函数包括：`numpy.sum()`、`numpy.sqrt()`、`sort()`、`max()` 等。

# %% [markdown]
# 完成后，你可以通过如下的UnitTest来测试你所实现的函数能否正常运行。

# %%
run_dist_tests()
run_KNN_tests()
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK
# Final Score of Euclidean Distance: 3/3
# Final Score of KNN Predict: 2/2

# %% [markdown]
# 完成上述代码后，你可以在`codes.py`中自行调整超参数$K$的大小，对测试数据集进行预测，并计算准确率。

# %%
predict(x_train, y_train, x_test, y_test)
# Out:
# Test accuracy: 83.0

# %% [markdown]
# 最终运行下述测试代码，查看你的实现是否正确。

# %%
run_final_tests()
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 1.621s
#
# OK
# Final Score of KNN Final: 5/5
